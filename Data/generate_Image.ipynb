# %%
from data_processing import _image_processing
import json
import os

# %%
# Define dataset directory and file path
RESDIR_PATH = os.path.join('.', 'Raw', 'CAFBRain_Dataset')

# %%
result_dict = _image_processing(RESDIR_PATH, image_captions=False)
# Out:
# All parameters:
# collateral_images_dict
# collateral_image_captions_dict
# powerpoints_images_dict
# powerpoints_image_captions_dict
# blog_posts_images_dict
# blog_posts_image_captions_dict

# %%
collateral_images_dict = result_dict["collateral_images_dict"]
powerpoints_images_dict = result_dict["powerpoints_images_dict"]
blog_posts_images_dict = result_dict["blog_posts_images_dict"]

# %%
# def save_nested_dict_of_arrays(data_dict, file_path):
#     flat_data = {}
#     for key, image_list in data_dict.items():
#         for idx, arr in enumerate(image_list):
#             flat_key = f"{key}_{idx}"
#             flat_data[flat_key] = arr
#     np.savez_compressed(file_path, **flat_data)
#     print(f"File '{file_path}' has been created.")

# %%
# file_path = os.path.join(dir_path, f"collateral_images_{sum(len(v) for v in collateral_images_dict.values())}.npz")
# save_nested_dict_of_arrays(collateral_images_dict, file_path)

# %%
# file_path = os.path.join(dir_path, f"powerpoints_images_{sum(len(v) for v in powerpoints_images_dict.values())}.npz")
# save_nested_dict_of_arrays(powerpoints_images_dict, file_path)

# %%
# file_path = os.path.join(dir_path, f"blog_images_{sum(len(v) for v in blog_posts_images_dict.values())}.npz")
# save_nested_dict_of_arrays(blog_posts_images_dict, file_path)
