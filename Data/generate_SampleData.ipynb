# %%
from data_processing import _data_processing
import json
import os

# %%
# Define dataset directory and file path
RESDIR_PATH = os.path.join('.', 'Raw', 'CAFBRain_Dataset')

# %%
result_dict = _data_processing(RESDIR_PATH)
# Out:
# All parameters:
# collateral_text_dict
# powerpoints_text_dict
# blog_posts_text_dict
# grant_text_dict
# youtube_posts_videos_dict
# youtube_posts_captions_dict

# %%
collateral_text_dict = result_dict["collateral_text_dict"]
powerpoints_text_dict = result_dict["powerpoints_text_dict"]
blog_posts_text_dict = result_dict["blog_posts_text_dict"]
grant_text_dict = result_dict["grant_text_dict"]
youtube_posts_captions_dict = result_dict["youtube_posts_captions_dict"]
# youtube_posts_videos_dict = result_dict["youtube_posts_videos_dict"]

# %%
dir_path = "./Processed/SampleData"
os.makedirs(dir_path, exist_ok=True)

# %%
# Count the number of entries
num_entries = len(collateral_text_dict)

# Define the file path
file_path = os.path.join(dir_path, f"collateral_text_{num_entries}.jsonl")

# Write to JSONL file with modified keys
with open(file_path, "w", encoding="utf-8") as f:
    for i, (key, value) in enumerate(collateral_text_dict.items()):
        new_key = key.split("_", 1)[1]  # Remove numeric prefix
        json_line = json.dumps({"key": new_key, "value": value}, ensure_ascii=False)

        if i < num_entries - 1:
            f.write(json_line + "\n")
        else:
            f.write(json_line)

print(f"File '{file_path}' has been created.")
# Out:
# File './Processed/SampleData\collateral_text_22.jsonl' has been created.

# %%
# Count the number of entries
num_entries = len(powerpoints_text_dict)

# Define the file path
file_path = os.path.join(dir_path, f"ppt_text_{num_entries}.jsonl")

# Write to JSONL file with modified keys
with open(file_path, "w", encoding="utf-8") as f:
    for i, (key, value) in enumerate(powerpoints_text_dict.items()):
        new_key = key.split("_", 1)[1]  # Remove numeric prefix
        json_line = json.dumps({"key": new_key, "value": value}, ensure_ascii=False)

        if i < num_entries - 1:
            f.write(json_line + "\n")
        else:
            f.write(json_line)

print(f"File '{file_path}' has been created.")
# Out:
# File './Processed/SampleData\ppt_text_7.jsonl' has been created.

# %%
# Count the number of entries
num_entries = len(blog_posts_text_dict)

# Define the file path
file_path = os.path.join(dir_path, f"blog_text_{num_entries}.jsonl")

# Write to JSONL file with modified keys
with open(file_path, "w", encoding="utf-8") as f:
    for i, (key, value) in enumerate(blog_posts_text_dict.items()):
        new_key = key.split("_", 1)[1]  # Remove numeric prefix
        json_line = json.dumps({"key": new_key, "value": value}, ensure_ascii=False)

        if i < num_entries - 1:
            f.write(json_line + "\n")
        else:
            f.write(json_line)

print(f"File '{file_path}' has been created.")
# Out:
# File './Processed/SampleData\blog_text_740.jsonl' has been created.

# %%
# Count the number of entries
num_entries = len(youtube_posts_captions_dict)

# Define the file path with the entry count
file_path = os.path.join(dir_path, f"yt_text_{num_entries}.jsonl")

# Write the dictionary to a JSONL file without a trailing newline
with open(file_path, "w", encoding="utf-8") as f:
    for i, (key, value) in enumerate(youtube_posts_captions_dict.items()):
        json_line = json.dumps({"key": key, "value": value}, ensure_ascii=False)

        if i < num_entries - 1:
            f.write(json_line + "\n")
        else:
            f.write(json_line)  # No newline for the last line

print(f"File '{file_path}' has been created.")
# Out:
# File './Processed/SampleData\yt_text_50.jsonl' has been created.

# %%
# Count the number of entries
num_entries = len(grant_text_dict)

# Define the file path
file_path = os.path.join(dir_path, f"grant_text_{num_entries}.jsonl")

# Write to JSONL file with modified keys
with open(file_path, "w", encoding="utf-8") as f:
    for i, (key, value) in enumerate(grant_text_dict.items()):

        json_line = json.dumps({"key": key, "value": value}, ensure_ascii=False)

        if i < num_entries - 1:
            f.write(json_line + "\n")
        else:
            f.write(json_line)

print(f"File '{file_path}' has been created.")
# Out:
# File './Processed/SampleData\grant_text_14.jsonl' has been created.
